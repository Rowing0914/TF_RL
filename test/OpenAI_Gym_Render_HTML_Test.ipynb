# %% [markdown]
# ## Testing Render Game screenshot on Notebook
# I have tried several methods to show the game screen on the notebook
#
# **link**
# - https://stackoverflow.com/questions/40195740/how-to-run-openai-gym-render-over-a-server
# - https://github.com/jakevdp/JSAnimation
# - http://mckinziebrandon.me/TensorflowNotebooks/2016/12/21/openai.html
# - https://nbviewer.jupyter.org/github/patrickmineault/xcorr-notebooks/blob/master/Render%20OpenAI%20gym%20as%20GIF.ipynb

# %% [markdown]
# ## In the end, these are the working example for me!
# 1. CartPole
# 2. Atari Games

# %% [markdown]
# ### 1. CartPole

# %%
# from JSAnimation.IPython_display import display_animation
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display, HTML

import gym

env = gym.make('CartPole-v0')

# Run a demo of the environment
observation = env.reset()
cum_reward = 0
frames = []
for t in range(1000):
    # Render into buffer. 
    # You will still see the window.
    frames.append(env.render(mode = 'rgb_array'))
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        break
env.close()

fig = plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
ax = fig.add_subplot(111);
patch = ax.imshow(frames[0])
plt.axis('off');

def animate(i):
    patch.set_data(frames[i])
anim = animation.FuncAnimation(fig, animate, frames=len(frames), interval=1, repeat=False)
HTML(anim.to_jshtml(default_mode='loop'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgd37f56765a84462d984bcbbdebd0eb8e">
#     <br>
#     <input id="_anim_sliderd37f56765a84462d984bcbbdebd0eb8e" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animd37f56765a84462d984bcbbdebd0eb8e.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="animd37f56765a84462d984bcbbdebd0eb8e.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selectd37f56765a84462d984bcbbdebd0eb8e" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgd37f56765a84462d984bcbbdebd0eb8e";
#     var slider_id = "_anim_sliderd37f56765a84462d984bcbbdebd0eb8e";
#     var loop_select_id = "_anim_loop_selectd37f56765a84462d984bcbbdebd0eb8e";
#     var frames = new Array(17);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAB+BJREFUeJzt3cGN2lAUQFE7mirSBmkjbeAypg7c\
# RtoIbUwbziIrJgrKkDvYmHMkFmDJeguMLt9gj8uyLAMAAJkvaw8AALA3AgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABi\
# AgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgvYlfM8Ded5WnsM\
# 4Mm9rD0AwC1EFLBlVrAAAGICCwAgJrAAAGICCwAgJrAAAGICC3hIh+Pp6nb/MgTWJLAAAGICCwAg\
# JrAAAGICCwAgJrAAAGICCwAgJrAAAGICCwAgJrAAAGICCwAgJrAAAGICCwAgJrAAAGICCwAgJrAA\
# AGICCwAgJrAAAGICCwAgJrAAAGICCwAgJrCAh3U4nq5uP8/TnSYBuCSwAABiAgsAICawAABiAgsA\
# ICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICawAABiAgsAICaw\
# AABiAgsAICawAABiAgsAICawAABiAgt4aIfjae0RAP4gsAAAYgILACAmsAAAYgILACAmsAAAYgIL\
# ACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAm\
# sAAAYgILACAmsIBdO8/T2iMAT0hgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExg\
# AQDEBBYAQExgAQDEBBYAQExgAQDEBBYAQExgAQDEBBawGeM43vT4rP3+6/4B3hNYAAAxgQUAEHtZ\
# ewCA0o+348Xz71/nlSYBnpnAAnbhfVhdvi6ygPtyihAAICawgIf3bbq+QvX6+vNO

# %% [markdown]
# ## 2. Atari Games

# %%
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('Breakout-v0')
env.reset()
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(100):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)
env.close()

# %% [markdown]
# ## Tests... painful to see them..lol

# %%
# from JSAnimation.IPython_display import display_animation
from matplotlib import animation
import matplotlib.pyplot as plt
from IPython.display import display

import gym

env = gym.make('CartPole-v0')

# Run a demo of the environment
observation = env.reset()
cum_reward = 0
frames = []
for t in range(1000):
    # Render into buffer. 
    # You will still see the window.
    frames.append(env.render(mode = 'rgb_array'))
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        break
env.close()

# %%
from IPython.display import HTML

# %%
plt.ioff()

fig = plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi = 72)
ax = fig.add_subplot(111);
patch = ax.imshow(frames[0])
plt.axis('off');

def animate(i):
    patch.set_data(frames[i])
anim = animation.FuncAnimation(fig, animate, frames=len(frames), interval=1, repeat=False)
HTML(anim.to_jshtml(default_mode='loop'))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6ec7642975424c138ec58417d4ddc01a">
#     <br>
#     <input id="_anim_slider6ec7642975424c138ec58417d4ddc01a" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6ec7642975424c138ec58417d4ddc01a.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6ec7642975424c138ec58417d4ddc01a.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6ec7642975424c138ec58417d4ddc01a" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6ec7642975424c138ec58417d4ddc01a";
#     var slider_id = "_anim_slider6ec7642975424c138ec58417d4ddc01a";
#     var loop_select_id = "_anim_loop_select6ec7642975424c138ec58417d4ddc01a";
#     var frames = new Array(15);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvOIA7rQAAB+dJREFUeJzt3cGN2lAUQFGIpoq0QdpIG7gm3Eba\
# CG1MG85iNpFmQBNxY/sz50isLKG3wObysb6Py7IsBwAAMt+2HgAA4NkILACAmMACAIgJLACAmMAC\
# AIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJ\
# LACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACA\
# mMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMAC\
# AIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJ\
# LACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACA\
# mMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMAC\
# AIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJ\
# LACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACA\
# mMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMAC\
# AIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJ\
# LACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACA\
# mMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMAC\
# AIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJ\
# LACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLACAmMACAIgJLGBY13k6XOdp6zEA3nnZegCAR92K\
# rNP5svIkAG+sYAEAxAQWAEBMYAFPyd+DwJYEFgBATGABAMQEFgBATGABAMQEFgBATGABAMQEFgBA\
# TGABAMQEFgBATGABAMQEFgBATGABAMQEFgBATGABAMQEFgBATGABAMQEFjCk6zxtPQLATQILACAm\
# sAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAAYgILACAmsAAA\
# YgILACAmsIDhXOfp7vHT+bLSJAAfE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQ\
# E1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQzlOk93j5/Ol5UmAbhNYAEAxAQWAEBM\
# YAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEAxAQWAEBMYAEA\
# xAQWAEBMYAFP43S+bD0CwOFwEFgAADmBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1gA\
# ADGBBQAQE1gAADGBBQAQE1gAADGBBQAQE1jAqo7H40Ov//XeACWBBQzj9+V889iPaV5xEoD7XrYe\
# AOBf/Hp9H1k/v4srYF+sYAHD+yi6ALYksAAAYgILGIaVKmAUAgsAICawgGG4mR0Y

# %%
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

env = gym.make('Breakout-v0')
env.reset()
img = plt.imshow(env.render(mode='rgb_array')) # only call this once
for _ in range(100):
    img.set_data(env.render(mode='rgb_array')) # just update the data
    display.display(plt.gcf())
    display.clear_output(wait=True)
    action = env.action_space.sample()
    env.step(action)
env.close()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython import display

def show_state(env, step=0, info=""):
    plt.figure(3)
    plt.clf()
    plt.imshow(env.render(mode='rgb_array'))
    plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
    plt.axis('off')

    display.clear_output(wait=True)
    display.display(plt.gcf())

# %%
env = gym.make('CartPole-v0')

# Run a demo of the environment
observation = env.reset()
cum_reward = 0
for t in range(1000):
    # Render into buffer. 
    # You will still see the window.
    show_state(env, step=t)
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    if done:
        break
env.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-58fe51fb1fd3> in <module>
#       7     # Render into buffer.
#       8     # You will still see the window.
# ----> 9     show_state(env, step=t)
#      10     action = env.action_space.sample()
#      11     observation, reward, done, info = env.step(action)
#
# <ipython-input-2-7c480f15fee7> in show_state(env, step, info)
#       7     plt.clf()
#       8     plt.imshow(env.render(mode='rgb_array'))
# ----> 9     plt.title("%s | Step: %d %s" % (env._spec.id,step, info))
#      10     plt.axis('off')
#      11
#
# AttributeError: 'TimeLimit' object has no attribute '_spec'

# %%
env.close()
